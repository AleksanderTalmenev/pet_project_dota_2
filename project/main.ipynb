# %%
import pandas as pd
import numpy as np

import seaborn as sns
import requests

# %%
tournament_id = 6880562712
count_match = 10

list_matches = []

for id in range(tournament_id, tournament_id + count_match):
    r = requests.get(f'https://api.opendota.com/api/matches/{id}')
    dict_data_match = r.json()
    if dict_data_match.get('error') == 'Not Found':
        continue
    list_matches.append(dict_data_match)
data = pd.DataFrame(list_matches)
data
# Out:
#      match_id  barracks_status_dire  barracks_status_radiant  chat  cluster  \
# 0  6880562712                    63                        0  None      153
# 1  6880562713                     0                        0  None      187
# 2  6880562714                     3                       63  None      145
# 3  6880562715                    63                        0  None      274
# 4  6880562716                     3                       63  None      183
# 5  6880562717                    48                       55  None      223
# 6  6880562718                    51                       63  None      185
# 7  6880562719                     0                        0  None      227
# 8  6880562720                     0                        0  None      151
# 9  6880562721                    12                        0  None      227
#
#   cosmetics  dire_score dire_team_id draft_timings  duration  ...  \
# 0      None          50         None          None      2904  ...
# 1      None          47         None          None      1256  ...
# 2      None          25         None          None      2037  ...
# 3      None          18         None          None      1620  ...
# 4      None          33         None          None      2509  ...
# 5      None          46         None          None      2410  ...
# 6      None          23         None          None      1226  ...
# 7      None          49         None          None      1074  ...
# 8      None          28         None          None       918  ...
# 9      None          56         None          None      3831  ...
#
#    tower_status_dire  tower_status_radiant  version   replay_salt  series_id  \
# 0               1828                     0     None  1.649216e+09        0.0
# 1                  0                     0     None           NaN        NaN
# 2                  4                  1982     None  5.859625e+08        0.0
# 3               1975                     0     None  1.446722e+09        0.0
# 4                  6                  1844     None  1.733218e+09        0.0
# 5                384                  1798     None  1.384285e+09        0.0
# 6                262                  1983     None  1.048081e+09        0.0
# 7                  0                     0     None           NaN        NaN
# 8                  0                     0     None           NaN        NaN
# 9               1584                     0     None  2.130100e+08        0.0
#
#    series_type                                            players  patch  \
# 0          0.0  [{'match_id': 6880562712, 'player_slot': 0, 'a...     51
# 1          NaN  [{'match_id': 6880562713, 'player_slot': 0, 'a...     51
# 2          0.0  [{'match_id': 6880562714, 'player_slot': 0, 'a...     51
# 3          0.0  [{'match_id': 6880562715, 'player_slot': 0, 'a...     51
# 4          0.0  [{'match_id': 6880562716, 'player_slot': 0, 'a...     51
# 5          0.0  [{'match_id': 6880562717, 'player_slot': 0, 'a...     51
# 6          0.0  [{'match_id': 6880562718, 'player_slot': 0, 'a...     51
# 7          NaN  [{'match_id': 6880562719, 'player_slot': 0, 'a...     51
# 8          NaN  [{'match_id': 6880562720, 'player_slot': 0, 'a...     51
# 9          0.0  [{'match_id': 6880562721, 'player_slot': 0, 'a...     51
#
#   region                                         replay_url
# 0      5  http://replay153.valve.net/570/6880562712_1649...
# 1      8                                                NaN
# 2     19  http://replay145.valve.net/570/6880562714_5859...
# 3      3  http://replay274.valve.net/570/6880562715_1446...
# 4      8  http://replay183.valve.net/570/6880562716_1733...
# 5     18  http://replay223.valve.net/570/6880562717_1384...
# 6      8  http://replay185.valve.net/570/6880562718_1048...
# 7     20                                                NaN
# 8      5                                                NaN
# 9     20  http://replay227.valve.net/570/6880562721_2130...
#
# [10 rows x 39 columns]

# %%
r = requests.get(f'https://api.opendota.com/api/matches/{6881452755}')
dict_data_match = r.json()
#del dict_data_match['chat']
dict_data_match['dire_team_id']
# Out:
# 8849837
